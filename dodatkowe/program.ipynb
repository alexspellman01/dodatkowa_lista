# %%
import pandas as pd

# %%
df = pd.read_csv('logs.txt',delimiter="|")
df.to_csv('logs_converted.csv', 
                  index = "sessionNo")
# df.set_index("sessionNo", inplace = True)

df.tail(100)
# Out:
#         sessionNo  startHour  startWeekday  duration  cCount cMinPrice  \
# 339030      39969         11             7  5768.257      27      5.99
# 339031      39969         11             7  5786.393      27      5.99
# 339032      39969         11             7  5841.934      27      5.99
# 339033      39969         11             7  5957.898      27      5.99
# 339034      39969         11             7  5975.679      27      5.99
# ...           ...        ...           ...       ...     ...       ...
# 339125      40000         11             7   267.412       6     64.95
# 339126      40000         11             7   273.040       6     64.95
# 339127      40000         11             7   369.357       6     64.95
# 339128      40000         11             7   391.880       6     64.95
# 339129      40000         11             7   403.495       6     64.95
#
#        cMaxPrice cSumPrice  bCount bMinPrice  ...          availability  \
# ...
